# %% [markdown]
# # Coding Lab 2: Programming
#
#
# Welcome to the second coding lab!
#
# CodingLab labs are meant to be interactive - so you should find another person to work together with on this notebook. For this lab, you can either work together on one notebook, or work together but you'll each still have fill out your own notebook for submission.
#
# CodingLabs are also meant to be exploratory. There are broad questions in the notebook that you should explore, and try to answer - but you are also very much encouraged to explore other related ideas as you go! If you explore something beyond what is required in the notebook, you're encouraged to leave that exploratory code in the notebook you submit.
#
# If you have a question about how something works / what something does - try it out, and see what happens! If you can't figure it out, reach out to your instructional staff - we're here to help!

# %% [markdown]
# **Reminder**: You may *not* be able to complete all of this in 2 hours, particularly the "challenges."  These are meant to help you gain mastery and provide additional practices, not to stress you out a ton. Make a concerted effort. Do your best to complete it. But, if you don't figure it all out, that's why we post answers for these!

# %% [markdown]
# ## Part 1: Variables
#
# Variables are used in Python to store values.

# %% [markdown]
# ### Defining Variables
#
# Declare a int, float, string, and boolean. Fill them with with any values you want.
#
# Call them `my_int`, `my_float`, `my_string` and `my_boolean`.

# %% [markdown]
# Use the following cells to check the types of the variables you write are as expected

# %%
type(my_int)

# %%
type(my_float)

# %%
type(my_string)

# %%
type(my_boolean)

# %% [markdown]
# ## Part 2: Operators & Comparisons
#
# Operators are used in Python to do things with variables.

# %% [markdown]
# ### Operator Questions

# %% [markdown]
# First - explore using Python operators. Make sure you can add and subtract numbers, concatenate strings, do boolean comparisons, etc.

# %%
## Do some exploring!

# %% [markdown]
# Once you have explored using operators, try to answer some quesions using them.
#
# Let's start with an example: is the multiplication of 13 and 15 greater than 200?

# %%
13 * 15 > 200

# %% [markdown]
# Similar to that example, try to answer the following questions using Python variables & comparisons:
# - Is the remainder of dividing 323 by 13 greater than 6?
# - Is 7 to the power of 3 greater than or equal to 300?
# - Is 49 squared greater than 2500 or (boolean comparison) is 14 to the power of 3 greater than 2500
# - Is 49 modulus 9 equal to 67 modulus 9 and (boolean comparison) is the sum 49 & 67 modulus 9 greater than 7

# %% [markdown]
# ### Operator Challenges
#
# The following are more challenging operator related questions. If they seem too tricky for now, just skip ahead to the next section.
#
# Some more comparisons, with variable assignment:
# - Set the variable `comp_1` to the result of whether 17 squared is not the same as 867 divided by 3
# - Set the variable `comp_2` to the result of whether 4^3 is less than 3^4 **and** also greater than the remainder of dividing 1234 by 99
#
# Bonus: both of the above questions can be written in (at least) two ways.
#
# If you found an answer to them, see if you can update the construction, changing at least one operator, to answer the question in a different way.
#
# Note: x^y indicates 'x to the power of y'

# %% [markdown]
# ### Operator Explorations.
#
# For each of the following questions, start by writing out a guess of what you think it might do.
#
# Then, test out each one by writing out some code.
#
# Finally, once you have answered the question, using some code, add a comment in the markdown here with the answer.
#
# Questions:
# - If you divide a float by an int, what is the type of the outcome? What about dividing an int by a float?
# - What happens if you multiply a string with a number?
# - The `+` sign works if you for adding numbers and for concatenating strings. Can you use `+` with a number and string in the same operation?
# - Since you can use `+` and `*` with strings, what happens if you try to substract two strings using `-`?

# %% [markdown]
# ## Part 3: Asserts
#
# You will notice, through the coding labs and assignments, code that looks somehing like `assert True`, in which the assert statement is used.
#
# Using assert basically says to `assert that the following code is True`.
#
# Or, slightly more formally `assert that the following code evaluates as True`.
#
# If the asserted code does not evaluate as True, it raises an error - meaning it interrupts the code execution because something went wrong.
#
# This can be used as a way to test that code does what you expect it to do - and is therefore part of how we will text your code programmatically.
#
# Because the use of `assert` will be common in course materials, let's take a moment to explore how it works and what happens when we use it.

# %%
# Declare a variable called `boolean` that  has type boolean, and passes the assert in the next cell

# %%
# Check that there is variable called `boolean` that is a boolean
assert type(boolean) == bool

# %%
# Check that the variable called `boolean` passes the assert
assert boolean

# %%
boolean

# %% [markdown]
# ###  Assert Explorations
#
# Now, explore using assert. What happens if you assert an integer, or a string?
#
# What happens if you assert None?
#
# Find at least one integer that raises an assertion error.

# %%
## EXPLORATION CODE HERE

# %% [markdown]
# ## Part 4: Collection types
#
# Collections are Python variable types than can store a 'collection' of items.

# %% [markdown]
# ### Collection Questions
#
# Create a list and a tuple. Fill them with with any values you want.
#
# Call them `my_list` and `my_tuple`.

# %% [markdown]
# Use the following cells to check the types of the variables you write are as expected

# %%
type(my_list)

# %%
type(my_tuple)

# %% [markdown]
# #### Declaring Collections
#
# Note that there can be more than one way to declare collections.
#
# As well as declaring them with '[]' and '()', we can use the list & tuple constructors, as shown below.

# %%
# Run me! - This creates another list & tuple, using the list & tuple constructors
some_list = list([1, 2, 3, 4, 5])
some_tuple = tuple(["peanut", "butter", "and", "jelly"])

print("'some_list' contains: \t", some_list)
print("'some_tuple' contains: \t", some_tuple)

# %% [markdown]
# Compare the types of these variables to your equivalent variables to confirm.
#
# In the cell below, write in the type of the objects that you expect them to be, and make sure the asserts pass.

# %%
# Fill in `_WRITE_IN_TYPE_HERE` with the type you expect each variable to be
assert isinstance(some_list, _WRITE_IN_TYPE_HERE_)
assert isinstance(some_tuple, _WRITE_IN_TYPE_HERE_)

# %% [markdown]
# ### Indexing
#
# Given the following list, do the following operations:
# - Get the length of the list (assign this to a variable `lst_len`)
# - Get the 1st element of the list (call the selection `ind1`)
# - Get the last element of the list (call the selection `ind2`)
# - Get the second to the fourth element of the list (call the selection `ind3`)
# - Get from the fifth element, to the end of the list (call the selection `ind4`)
# - Get every second element of the list, starting at the first element (call the selection `ind5`)
# - Get every second element of the list, starting at the second element (call the selection `ind6`)

# %%
my_lst = ['a', True, 12, 'tomato', False, None, 23, 'python', [], 5.5]

# %% [markdown]
# ## Part 5: Conditionals
#
# Conditionals a form of control flow for executing certain code if a specific condition is met.

# %% [markdown]
# ### Conditional Questions
#
# In this part, we will re-visit some questions about conditionals, and start combining them together with collections.
#
# Make sure you can use if/elif/else statements to control which code blocks are run.

# %% [markdown]
# #### Controlling Output With Conditionals I
#
# Using the code below, keep updating the variable value to make sure you can make the conditional return each of the possibilities.

# %%
# ToDo: Update value to control what gets executed
value = 10

# This code provided
if isinstance(value, int):
    if value < 10:
        result = 'small value'
    if value >= 10:
        result = 'big value'
else:
    result = 'false value'

# %%
print(result)

# %% [markdown]
# #### Controlling Output With Conditionals II
#
# In the cell below, first write something into each result assignment related to  for example, it could be "B1 is False & B2 is True").
#
# Then make sure you can change values of b1 & b2 to make the program execute each option.

# %%
# ToDo: Update b1 & b2 to control what gets executed
b1 = False
b2 = False

# Next, try this out
if b1 and not b2:
    result = ''
elif not b1 and b2:
    result = ''
elif b1 and b2:
    result = ''
else:
    result = ''

# %%
print(result)

# %% [markdown]
# ### Conditional Challenges
#
# The following are more challenging questions relating to conditional statements. If they seem too tricky for now, just skip ahead to the next section.

# %% [markdown]
# #### Conditional Challenge #1
#
# Write a conditional that prints "Found it" if a given `val_2` is a multiple of 10, otherwise prints "Nope."

# %% [markdown]
# #### Conditional Challenge #2
#
# Input: assumes a variable `val_1`, that can be either a string or an integer
#
# Output: based on the conditions, this code block will assign a variable called `output` to be a boolean
#
# Use conditions to check whether `val_1` is a string or an integer object:
# - If it is a string, check whether it's length is greater then 8
#     - If so, set the value `output` to True
# - If it is an integer, compare whether it is less than 100
#     - If so, set the value `output` to True
# - Else, set output to False

# %% [markdown]
# ### Operator Explorations
#
# For each of the following questions, start by writing out a guess of what you think it might do.
#
# Then, test out each one by writing out some code.
#
# Finally, once you have answered the question, using some code, add a comment in the markdown here with the answer.
#
# Questions:
# - Can you include multiple conditions in an if statement?
#     - If think so, write an if statement that tests multiple conditions.
# - What happens if you put an if statement inside an if statement? When would such a statement run?
#     - To explore this, write an if statement that has an embedded if statement in it.

# %%
## YOUR EXPLORATIONS HERE

# %% [markdown]
# ## Part 6: Loops
#
# We will now explore two ways to iterate over data in Python - `for` and `while` loops.
#
# Each type of loop performs its respective code block until certain conditions are met. Here, we will explore what those conditions are.
#
# Note: "iterate" means to perform an action repeatedly
#
# Note: Sometimes, we accidentally make loops that never end.
# - If that happens, "break" the cell by selecting it and then pressing "ctrl+c". Alternatively, press the "stop" button (square icon) in the Jupyter toolbar.

# %% [markdown]
# #### Loops Q1
#
# First, declare a variable called `counter` that has type int and value zero.
#
# Then write a while loop that runs 10 times and use 'counter' to track how many times the loop runs.

# %%
# Check that (after the loop runs) that there is a variable called `counter` that has value 10
assert counter == 10

# %% [markdown]
# #### Infinite Loops
#
# The while loop below will run indefinitely unless someone puts a stop to it!
#
# Add your own code that causes the loop to exit when the `counter` variable reaches 10. You can use `break` to do this.
#
# Note: Sometimes, we accidentally make loops that never end - try that by running the cell below before adding
#
# If that happens, interrupt the cell by selecting it and then pressing "ctrl+c". Alternatively, press the "stop" button (square icon) in the Jupyter toolbar.

# %%
counter = 0

while True:
    
    print("the value of 'counter' = {}".format(counter))
    counter +=1
    
    ## YOUR CODE HERE
# Out:
# the value of 'counter' = 0
# the value of 'counter' = 1
# the value of 'counter' = 2
# the value of 'counter' = 3
# the value of 'counter' = 4
# the value of 'counter' = 5
# the value of 'counter' = 6
# the value of 'counter' = 7
# the value of 'counter' = 8
# the value of 'counter' = 9
# the value of 'counter' = 10
# the value of 'counter' = 11
# the value of 'counter' = 12
# the value of 'counter' = 13
# the value of 'counter' = 14
# the value of 'counter' = 15
# the value of 'counter' = 16
# the value of 'counter' = 17
# the value of 'counter' = 18
# the value of 'counter' = 19
# the value of 'counter' = 20
# the value of 'counter' = 21
# the value of 'counter' = 22
# the value of 'counter' = 23
# the value of 'counter' = 24
# the value of 'counter' = 25
# the value of 'counter' = 26
# the value of 'counter' = 27
# the value of 'counter' = 28
# the value of 'counter' = 29
# the value of 'counter' = 30
# the value of 'counter' = 31
# the value of 'counter' = 32
# the value of 'counter' = 33
# the value of 'counter' = 34
# the value of 'counter' = 35
# the value of 'counter' = 36
# the value of 'counter' = 37
# the value of 'counter' = 38
# the value of 'counter' = 39
# the value of 'counter' = 40
# the value of 'counter' = 41
# the value of 'counter' = 42
# the value of 'counter' = 43
# the value of 'counter' = 44
# the value of 'counter' = 45
# the value of 'counter' = 46
# the value of 'counter' = 47
# the value of 'counter' = 48
# the value of 'counter' = 49
# the value of 'counter' = 50
# the value of 'counter' = 51
# the value of 'counter' = 52
# the value of 'counter' = 53
# the value of 'counter' = 54
# the value of 'counter' = 55
# the value of 'counter' = 56
# the value of 'counter' = 57
# the value of 'counter' = 58
# the value of 'counter' = 59
# the value of 'counter' = 60
# the value of 'counter' = 61
# the value of 'counter' = 62
# the value of 'counter' = 63
# the value of 'counter' = 64
# the value of 'counter' = 65
# the value of 'counter' = 66
# the value of 'counter' = 67
# the value of 'counter' = 68
# the value of 'counter' = 69
# the value of 'counter' = 70
# the value of 'counter' = 71
# the value of 'counter' = 72
# the value of 'counter' = 73
# the value of 'counter' = 74
# the value of 'counter' = 75
# the value of 'counter' = 76
# the value of 'counter' = 77
# the value of 'counter' = 78
# the value of 'counter' = 79
# the value of 'counter' = 80
# the value of 'counter' = 81
# the value of 'counter' = 82
# the value of 'counter' = 83
# the value of 'counter' = 84
# the value of 'counter' = 85
# the value of 'counter' = 86
# the value of 'counter' = 87
# the value of 'counter' = 88
# the value of 'counter' = 89
# the value of 'counter' = 90
# the value of 'counter' = 91
# the value of 'counter' = 92
# the value of 'counter' = 93
# the value of 'counter' = 94
# the value of 'counter' = 95
# the value of 'counter' = 96
# the value of 'counter' = 97
# the value of 'counter' = 98
# the value of 'counter' = 99
# the value of 'counter' = 100
# the value of 'counter' = 101
# the value of 'counter' = 102
# the value of 'counter' = 103
# the value of 'counter' = 104
# the value of 'counter' = 105
# the value of 'counter' = 106
# the value of 'counter' = 107
# the value of 'counter' = 108
# the value of 'counter' = 109
# the value of 'counter' = 110
# the value of 'counter' = 111
# the value of 'counter' = 112
# the value of 'counter' = 113
# the value of 'counter' = 114
# the value of 'counter' = 115
# the value of 'counter' = 116
# the value of 'counter' = 117
# the value of 'counter' = 118
# the value of 'counter' = 119
# the value of 'counter' = 120
# the value of 'counter' = 121
# the value of 'counter' = 122
# the value of 'counter' = 123
# the value of 'counter' = 124
# the value of 'counter' = 125
# the value of 'counter' = 126
# the value of 'counter' = 127
# the value of 'counter' = 128
# the value of 'counter' = 129
# the value of 'counter' = 130
# the value of 'counter' = 131
# the value of 'counter' = 132
# the value of 'counter' = 133
# the value of 'counter' = 134
# the value of 'counter' = 135
# the value of 'counter' = 136
# the value of 'counter' = 137
# the value of 'counter' = 138
# the value of 'counter' = 139
# the value of 'counter' = 140
# the value of 'counter' = 141
# the value of 'counter' = 142
# the value of 'counter' = 143
# the value of 'counter' = 144
# the value of 'counter' = 145
# the value of 'counter' = 146
# the value of 'counter' = 147
# the value of 'counter' = 148
# the value of 'counter' = 149
# the value of 'counter' = 150
# the value of 'counter' = 151
# the value of 'counter' = 152
# the value of 'counter' = 153
# the value of 'counter' = 154
# the value of 'counter' = 155
# the value of 'counter' = 156
# the value of 'counter' = 157
# the value of 'counter' = 158
# the value of 'counter' = 159
# the value of 'counter' = 160
# the value of 'counter' = 161
# the value of 'counter' = 162
# the value of 'counter' = 163
# the value of 'counter' = 164
# the value of 'counter' = 165
# the value of 'counter' = 166
# the value of 'counter' = 167
# the value of 'counter' = 168
# the value of 'counter' = 169
# the value of 'counter' = 170
# the value of 'counter' = 171
# the value of 'counter' = 172
# the value of 'counter' = 173
# the value of 'counter' = 174
# the value of 'counter' = 175
# the value of 'counter' = 176
# the value of 'counter' = 177
# the value of 'counter' = 178
# the value of 'counter' = 179
# the value of 'counter' = 180
# the value of 'counter' = 181
# the value of 'counter' = 182
# the value of 'counter' = 183
# the value of 'counter' = 184
# the value of 'counter' = 185
# the value of 'counter' = 186
# the value of 'counter' = 187
# the value of 'counter' = 188
# the value of 'counter' = 189
# the value of 'counter' = 190
# the value of 'counter' = 191
# the value of 'counter' = 192
# the value of 'counter' = 193
# the value of 'counter' = 194
# the value of 'counter' = 195
# the value of 'counter' = 196
# the value of 'counter' = 197
# the value of 'counter' = 198
# the value of 'counter' = 199
# the value of 'counter' = 200
# the value of 'counter' = 201
# the value of 'counter' = 202
# the value of 'counter' = 203
# the value of 'counter' = 204
# the value of 'counter' = 205
# the value of 'counter' = 206
# the value of 'counter' = 207
# the value of 'counter' = 208
# the value of 'counter' = 209
# the value of 'counter' = 210
# the value of 'counter' = 211
# the value of 'counter' = 212
# the value of 'counter' = 213
# the value of 'counter' = 214
# the value of 'counter' = 215
# the value of 'counter' = 216
# the value of 'counter' = 217
# the value of 'counter' = 218
# the value of 'counter' = 219
# the value of 'counter' = 220
# the value of 'counter' = 221
# the value of 'counter' = 222
# the value of 'counter' = 223
# the value of 'counter' = 224
# the value of 'counter' = 225
# the value of 'counter' = 226
# the value of 'counter' = 227
# the value of 'counter' = 228
# the value of 'counter' = 229
# the value of 'counter' = 230
# the value of 'counter' = 231
# the value of 'counter' = 232
# the value of 'counter' = 233
# the value of 'counter' = 234
# the value of 'counter' = 235
# the value of 'counter' = 236
# the value of 'counter' = 237
# the value of 'counter' = 238
# the value of 'counter' = 239
# the value of 'counter' = 240
# the value of 'counter' = 241
# the value of 'counter' = 242
# the value of 'counter' = 243
# the value of 'counter' = 244
# the value of 'counter' = 245
# the value of 'counter' = 246
# the value of 'counter' = 247
# the value of 'counter' = 248
# the value of 'counter' = 249
# the value of 'counter' = 250
# the value of 'counter' = 251
# the value of 'counter' = 252
# the value of 'counter' = 253
# the value of 'counter' = 254
# the value of 'counter' = 255
# the value of 'counter' = 256
# the value of 'counter' = 257
# the value of 'counter' = 258
# the value of 'counter' = 259
# the value of 'counter' = 260
# the value of 'counter' = 261
# the value of 'counter' = 262
# the value of 'counter' = 263
# the value of 'counter' = 264
# the value of 'counter' = 265
# the value of 'counter' = 266
# the value of 'counter' = 267
# the value of 'counter' = 268
# the value of 'counter' = 269
# the value of 'counter' = 270
# the value of 'counter' = 271
# the value of 'counter' = 272
# the value of 'counter' = 273
# the value of 'counter' = 274
# the value of 'counter' = 275
# the value of 'counter' = 276
# the value of 'counter' = 277
# the value of 'counter' = 278
# the value of 'counter' = 279
# the value of 'counter' = 280
# the value of 'counter' = 281
# the value of 'counter' = 282
# the value of 'counter' = 283
# the value of 'counter' = 284
# the value of 'counter' = 285
# the value of 'counter' = 286
# the value of 'counter' = 287
# the value of 'counter' = 288
# the value of 'counter' = 289
# the value of 'counter' = 290
# the value of 'counter' = 291
# the value of 'counter' = 292
# the value of 'counter' = 293
# the value of 'counter' = 294
# the value of 'counter' = 295
# the value of 'counter' = 296
# the value of 'counter' = 297
# the value of 'counter' = 298
# the value of 'counter' = 299
# the value of 'counter' = 300
# the value of 'counter' = 301
# the value of 'counter' = 302
# the value of 'counter' = 303
# the value of 'counter' = 304
# the value of 'counter' = 305
# the value of 'counter' = 306
# the value of 'counter' = 307
# the value of 'counter' = 308
# the value of 'counter' = 309
# the value of 'counter' = 310
# the value of 'counter' = 311
# the value of 'counter' = 312
# the value of 'counter' = 313
# the value of 'counter' = 314
# the value of 'counter' = 315
# the value of 'counter' = 316
# the value of 'counter' = 317
# the value of 'counter' = 318
# the value of 'counter' = 319
# the value of 'counter' = 320
# the value of 'counter' = 321
# the value of 'counter' = 322
# the value of 'counter' = 323
# the value of 'counter' = 324
# the value of 'counter' = 325
# the value of 'counter' = 326
# the value of 'counter' = 327
# the value of 'counter' = 328
# the value of 'counter' = 329
# the value of 'counter' = 330
# the value of 'counter' = 331
# the value of 'counter' = 332
# the value of 'counter' = 333
# the value of 'counter' = 334
# the value of 'counter' = 335
# the value of 'counter' = 336
# the value of 'counter' = 337
# the value of 'counter' = 338
# the value of 'counter' = 339
# the value of 'counter' = 340
# the value of 'counter' = 341
# the value of 'counter' = 342
# the value of 'counter' = 343
# the value of 'counter' = 344
# the value of 'counter' = 345
# the value of 'counter' = 346
# the value of 'counter' = 347
# the value of 'counter' = 348
# the value of 'counter' = 349
# the value of 'counter' = 350
# the value of 'counter' = 351
# the value of 'counter' = 352
# the value of 'counter' = 353
# the value of 'counter' = 354
# the value of 'counter' = 355
# the value of 'counter' = 356
# the value of 'counter' = 357
# the value of 'counter' = 358
# the value of 'counter' = 359
# the value of 'counter' = 360
# the value of 'counter' = 361
# the value of 'counter' = 362
# the value of 'counter' = 363
# the value of 'counter' = 364
# the value of 'counter' = 365
# the value of 'counter' = 366
# the value of 'counter' = 367
# the value of 'counter' = 368
# the value of 'counter' = 369
# the value of 'counter' = 370
# the value of 'counter' = 371
# the value of 'counter' = 372
# the value of 'counter' = 373
# the value of 'counter' = 374
# the value of 'counter' = 375
# the value of 'counter' = 376
# the value of 'counter' = 377
# the value of 'counter' = 378
# the value of 'counter' = 379
# the value of 'counter' = 380
# the value of 'counter' = 381
# the value of 'counter' = 382
# the value of 'counter' = 383
# the value of 'counter' = 384
# the value of 'counter' = 385
# the value of 'counter' = 386
# the value of 'counter' = 387
# the value of 'counter' = 388
# the value of 'counter' = 389
# the value of 'counter' = 390
# the value of 'counter' = 391
# the value of 'counter' = 392
# the value of 'counter' = 393
# the value of 'counter' = 394
# the value of 'counter' = 395
# the value of 'counter' = 396
# the value of 'counter' = 397
# the value of 'counter' = 398
# the value of 'counter' = 399
# the value of 'counter' = 400
# the value of 'counter' = 401
# the value of 'counter' = 402
# the value of 'counter' = 403
# the value of 'counter' = 404
# the value of 'counter' = 405
# the value of 'counter' = 406
# the value of 'counter' = 407
# the value of 'counter' = 408
# the value of 'counter' = 409
# the value of 'counter' = 410
# the value of 'counter' = 411
# the value of 'counter' = 412
# the value of 'counter' = 413
# the value of 'counter' = 414
# the value of 'counter' = 415
# the value of 'counter' = 416
# the value of 'counter' = 417
# the value of 'counter' = 418
# the value of 'counter' = 419
# the value of 'counter' = 420
# the value of 'counter' = 421
# the value of 'counter' = 422
# the value of 'counter' = 423
# the value of 'counter' = 424
# the value of 'counter' = 425
# the value of 'counter' = 426
# the value of 'counter' = 427
# the value of 'counter' = 428
# the value of 'counter' = 429
# the value of 'counter' = 430
# the value of 'counter' = 431
# the value of 'counter' = 432
# the value of 'counter' = 433
# the value of 'counter' = 434
# the value of 'counter' = 435
# the value of 'counter' = 436
# the value of 'counter' = 437
# the value of 'counter' = 438
# the value of 'counter' = 439
# the value of 'counter' = 440
# the value of 'counter' = 441
# the value of 'counter' = 442
# the value of 'counter' = 443
# the value of 'counter' = 444
# the value of 'counter' = 445
# the value of 'counter' = 446
# the value of 'counter' = 447
# the value of 'counter' = 448
# the value of 'counter' = 449
# the value of 'counter' = 450
# the value of 'counter' = 451
# the value of 'counter' = 452
# the value of 'counter' = 453
# the value of 'counter' = 454
# the value of 'counter' = 455
# the value of 'counter' = 456
# the value of 'counter' = 457
# the value of 'counter' = 458
# the value of 'counter' = 459
# the value of 'counter' = 460
# the value of 'counter' = 461
# the value of 'counter' = 462
# the value of 'counter' = 463
# the value of 'counter' = 464
# the value of 'counter' = 465
# the value of 'counter' = 466
# the value of 'counter' = 467
# the value of 'counter' = 468
# the value of 'counter' = 469
# the value of 'counter' = 470
# the value of 'counter' = 471
# the value of 'counter' = 472
# the value of 'counter' = 473
# the value of 'counter' = 474
# the value of 'counter' = 475
# the value of 'counter' = 476
# the value of 'counter' = 477
# the value of 'counter' = 478
# the value of 'counter' = 479
# the value of 'counter' = 480
# the value of 'counter' = 481
# the value of 'counter' = 482
# the value of 'counter' = 483
# the value of 'counter' = 484
# the value of 'counter' = 485
# the value of 'counter' = 486
# the value of 'counter' = 487
# the value of 'counter' = 488
# the value of 'counter' = 489
# the value of 'counter' = 490
# the value of 'counter' = 491
# the value of 'counter' = 492
# the value of 'counter' = 493
# the value of 'counter' = 494
# the value of 'counter' = 495
# the value of 'counter' = 496
# the value of 'counter' = 497
# the value of 'counter' = 498
# the value of 'counter' = 499
# the value of 'counter' = 500
# the value of 'counter' = 501
# the value of 'counter' = 502
# the value of 'counter' = 503
# the value of 'counter' = 504
# the value of 'counter' = 505
# the value of 'counter' = 506
# the value of 'counter' = 507
# the value of 'counter' = 508
# the value of 'counter' = 509
# the value of 'counter' = 510
# the value of 'counter' = 511
# the value of 'counter' = 512
# the value of 'counter' = 513
# the value of 'counter' = 514
# the value of 'counter' = 515
# the value of 'counter' = 516
# the value of 'counter' = 517
# the value of 'counter' = 518
# the value of 'counter' = 519
# the value of 'counter' = 520
# the value of 'counter' = 521
# the value of 'counter' = 522
# the value of 'counter' = 523
# the value of 'counter' = 524
# the value of 'counter' = 525
# the value of 'counter' = 526
# the value of 'counter' = 527
# the value of 'counter' = 528
# the value of 'counter' = 529
# the value of 'counter' = 530
# the value of 'counter' = 531
# the value of 'counter' = 532
# the value of 'counter' = 533
# the value of 'counter' = 534
# the value of 'counter' = 535
# the value of 'counter' = 536
# the value of 'counter' = 537
# the value of 'counter' = 538
# the value of 'counter' = 539
# the value of 'counter' = 540
# the value of 'counter' = 541
# the value of 'counter' = 542
# the value of 'counter' = 543
# the value of 'counter' = 544
# the value of 'counter' = 545
# the value of 'counter' = 546
# the value of 'counter' = 547
# the value of 'counter' = 548
# the value of 'counter' = 549
# the value of 'counter' = 550
# the value of 'counter' = 551
# the value of 'counter' = 552
# the value of 'counter' = 553
# the value of 'counter' = 554
# the value of 'counter' = 555
# the value of 'counter' = 556
# the value of 'counter' = 557
# the value of 'counter' = 558
# the value of 'counter' = 559
# the value of 'counter' = 560
# the value of 'counter' = 561
# the value of 'counter' = 562
# the value of 'counter' = 563
# the value of 'counter' = 564
# the value of 'counter' = 565
# the value of 'counter' = 566
# the value of 'counter' = 567
# the value of 'counter' = 568
# the value of 'counter' = 569
# the value of 'counter' = 570
# the value of 'counter' = 571
# the value of 'counter' = 572
# the value of 'counter' = 573
# the value of 'counter' = 574
# the value of 'counter' = 575
# the value of 'counter' = 576
# the value of 'counter' = 577
# the value of 'counter' = 578
# the value of 'counter' = 579
# the value of 'counter' = 580
# the value of 'counter' = 581
# the value of 'counter' = 582
# the value of 'counter' = 583
# the value of 'counter' = 584
# the value of 'counter' = 585
# the value of 'counter' = 586
# the value of 'counter' = 587
# the value of 'counter' = 588
# the value of 'counter' = 589
# the value of 'counter' = 590
# the value of 'counter' = 591
# the value of 'counter' = 592
# the value of 'counter' = 593
# the value of 'counter' = 594
# the value of 'counter' = 595
# the value of 'counter' = 596
# the value of 'counter' = 597
# the value of 'counter' = 598
# the value of 'counter' = 599
# the value of 'counter' = 600
# the value of 'counter' = 601
# the value of 'counter' = 602
# the value of 'counter' = 603
# the value of 'counter' = 604
# the value of 'counter' = 605
# the value of 'counter' = 606
# the value of 'counter' = 607
# the value of 'counter' = 608
# the value of 'counter' = 609
# the value of 'counter' = 610
# the value of 'counter' = 611
# the value of 'counter' = 612
# the value of 'counter' = 613
# the value of 'counter' = 614
# the value of 'counter' = 615
# the value of 'counter' = 616
# the value of 'counter' = 617
# the value of 'counter' = 618
# the value of 'counter' = 619
# the value of 'counter' = 620
# the value of 'counter' = 621
# the value of 'counter' = 622
# the value of 'counter' = 623
# the value of 'counter' = 624
# the value of 'counter' = 625
# the value of 'counter' = 626
# the value of 'counter' = 627
# the value of 'counter' = 628
# the value of 'counter' = 629
# the value of 'counter' = 630
# the value of 'counter' = 631
# the value of 'counter' = 632
# the value of 'counter' = 633
# the value of 'counter' = 634
# the value of 'counter' = 635
# the value of 'counter' = 636
# the value of 'counter' = 637
# the value of 'counter' = 638
# the value of 'counter' = 639
# the value of 'counter' = 640
# the value of 'counter' = 641
# the value of 'counter' = 642
# the value of 'counter' = 643
# the value of 'counter' = 644
# the value of 'counter' = 645
# the value of 'counter' = 646
# the value of 'counter' = 647
# the value of 'counter' = 648
# the value of 'counter' = 649
# the value of 'counter' = 650
# the value of 'counter' = 651
# the value of 'counter' = 652
# the value of 'counter' = 653
# the value of 'counter' = 654
# the value of 'counter' = 655
# the value of 'counter' = 656
# the value of 'counter' = 657
# the value of 'counter' = 658
# the value of 'counter' = 659
# the value of 'counter' = 660
# the value of 'counter' = 661
# the value of 'counter' = 662
# the value of 'counter' = 663
# the value of 'counter' = 664
# the value of 'counter' = 665
# the value of 'counter' = 666
# the value of 'counter' = 667
# the value of 'counter' = 668
# the value of 'counter' = 669
# the value of 'counter' = 670
# the value of 'counter' = 671
# the value of 'counter' = 672
# the value of 'counter' = 673
# the value of 'counter' = 674
# the value of 'counter' = 675
# the value of 'counter' = 676
# the value of 'counter' = 677
# the value of 'counter' = 678
# the value of 'counter' = 679
# the value of 'counter' = 680
# the value of 'counter' = 681
# the value of 'counter' = 682
# the value of 'counter' = 683
# the value of 'counter' = 684
# the value of 'counter' = 685
# the value of 'counter' = 686
# the value of 'counter' = 687
# the value of 'counter' = 688
# the value of 'counter' = 689
# the value of 'counter' = 690
# the value of 'counter' = 691
# the value of 'counter' = 692
# the value of 'counter' = 693
# the value of 'counter' = 694
# the value of 'counter' = 695
# the value of 'counter' = 696
# the value of 'counter' = 697
# the value of 'counter' = 698
# the value of 'counter' = 699
# the value of 'counter' = 700
# the value of 'counter' = 701
# the value of 'counter' = 702
# the value of 'counter' = 703
# the value of 'counter' = 704
# the value of 'counter' = 705
# the value of 'counter' = 706
# the value of 'counter' = 707
# the value of 'counter' = 708
# the value of 'counter' = 709
# the value of 'counter' = 710
# the value of 'counter' = 711
# the value of 'counter' = 712
# the value of 'counter' = 713
# the value of 'counter' = 714
# the value of 'counter' = 715
# the value of 'counter' = 716
# the value of 'counter' = 717
# the value of 'counter' = 718
# the value of 'counter' = 719
# the value of 'counter' = 720
# the value of 'counter' = 721
# the value of 'counter' = 722
# the value of 'counter' = 723
# the value of 'counter' = 724
# the value of 'counter' = 725
# the value of 'counter' = 726
# the value of 'counter' = 727
# the value of 'counter' = 728
# the value of 'counter' = 729
# the value of 'counter' = 730
# the value of 'counter' = 731
# the value of 'counter' = 732
# the value of 'counter' = 733
# the value of 'counter' = 734
# the value of 'counter' = 735
# the value of 'counter' = 736
# the value of 'counter' = 737
# the value of 'counter' = 738
# the value of 'counter' = 739
# the value of 'counter' = 740
# the value of 'counter' = 741
# the value of 'counter' = 742
# the value of 'counter' = 743
# the value of 'counter' = 744
# the value of 'counter' = 745
# the value of 'counter' = 746
# the value of 'counter' = 747
# the value of 'counter' = 748
# the value of 'counter' = 749
# the value of 'counter' = 750
# the value of 'counter' = 751
# the value of 'counter' = 752
# the value of 'counter' = 753
# the value of 'counter' = 754
# the value of 'counter' = 755
# the value of 'counter' = 756
# the value of 'counter' = 757
# the value of 'counter' = 758
# the value of 'counter' = 759
# the value of 'counter' = 760
# the value of 'counter' = 761
# the value of 'counter' = 762
# the value of 'counter' = 763
# the value of 'counter' = 764
# the value of 'counter' = 765
# the value of 'counter' = 766
# the value of 'counter' = 767
# the value of 'counter' = 768
# the value of 'counter' = 769
# the value of 'counter' = 770
# the value of 'counter' = 771
# the value of 'counter' = 772
# the value of 'counter' = 773
# the value of 'counter' = 774
# the value of 'counter' = 775
# the value of 'counter' = 776
# the value of 'counter' = 777
# the value of 'counter' = 778
# the value of 'counter' = 779
# the value of 'counter' = 780
# the value of 'counter' = 781
# the value of 'counter' = 782
# the value of 'counter' = 783
# the value of 'counter' = 784
# the value of 'counter' = 785
# the value of 'counter' = 786
# the value of 'counter' = 787
# the value of 'counter' = 788
# the value of 'counter' = 789
# the value of 'counter' = 790
# the value of 'counter' = 791
# the value of 'counter' = 792
# the value of 'counter' = 793
# the value of 'counter' = 794
# the value of 'counter' = 795
# the value of 'counter' = 796
# the value of 'counter' = 797
# the value of 'counter' = 798
# the value of 'counter' = 799
# the value of 'counter' = 800
# the value of 'counter' = 801
# the value of 'counter' = 802
# the value of 'counter' = 803
# the value of 'counter' = 804
# the value of 'counter' = 805
# the value of 'counter' = 806
# the value of 'counter' = 807
# the value of 'counter' = 808
# the value of 'counter' = 809
# the value of 'counter' = 810
# the value of 'counter' = 811
# the value of 'counter' = 812
# the value of 'counter' = 813
# the value of 'counter' = 814
# the value of 'counter' = 815
# the value of 'counter' = 816
# the value of 'counter' = 817
# the value of 'counter' = 818
# the value of 'counter' = 819
# the value of 'counter' = 820
# the value of 'counter' = 821
# the value of 'counter' = 822
# the value of 'counter' = 823
# the value of 'counter' = 824
# the value of 'counter' = 825
# the value of 'counter' = 826
# the value of 'counter' = 827
# the value of 'counter' = 828
# the value of 'counter' = 829
# the value of 'counter' = 830
# the value of 'counter' = 831
# the value of 'counter' = 832
# the value of 'counter' = 833
# the value of 'counter' = 834
# the value of 'counter' = 835
# the value of 'counter' = 836
# the value of 'counter' = 837
# the value of 'counter' = 838
# the value of 'counter' = 839
# the value of 'counter' = 840
# the value of 'counter' = 841
# the value of 'counter' = 842
# the value of 'counter' = 843
# the value of 'counter' = 844
# the value of 'counter' = 845
# the value of 'counter' = 846
# the value of 'counter' = 847
# the value of 'counter' = 848
# the value of 'counter' = 849
# the value of 'counter' = 850
# the value of 'counter' = 851
# the value of 'counter' = 852
# the value of 'counter' = 853
# the value of 'counter' = 854
# the value of 'counter' = 855
# the value of 'counter' = 856
# the value of 'counter' = 857
# the value of 'counter' = 858
# the value of 'counter' = 859
# the value of 'counter' = 860
# the value of 'counter' = 861
# the value of 'counter' = 862
# the value of 'counter' = 863
# the value of 'counter' = 864
# the value of 'counter' = 865
# the value of 'counter' = 866
# the value of 'counter' = 867
# the value of 'counter' = 868
# the value of 'counter' = 869
# the value of 'counter' = 870
# the value of 'counter' = 871
# the value of 'counter' = 872
# the value of 'counter' = 873
# the value of 'counter' = 874
# the value of 'counter' = 875
# the value of 'counter' = 876
# the value of 'counter' = 877
# the value of 'counter' = 878
# the value of 'counter' = 879
# the value of 'counter' = 880
# the value of 'counter' = 881
# the value of 'counter' = 882
# the value of 'counter' = 883
# the value of 'counter' = 884
# the value of 'counter' = 885
# the value of 'counter' = 886
# the value of 'counter' = 887
# the value of 'counter' = 888
# the value of 'counter' = 889
# the value of 'counter' = 890
# the value of 'counter' = 891
# the value of 'counter' = 892
# the value of 'counter' = 893
# the value of 'counter' = 894
# the value of 'counter' = 895
# the value of 'counter' = 896
# the value of 'counter' = 897
# the value of 'counter' = 898
# the value of 'counter' = 899
# the value of 'counter' = 900
# the value of 'counter' = 901
# the value of 'counter' = 902
# the value of 'counter' = 903
# the value of 'counter' = 904
# the value of 'counter' = 905
# the value of 'counter' = 906
# the value of 'counter' = 907
# the value of 'counter' = 908
# the value of 'counter' = 909
# the value of 'counter' = 910
# the value of 'counter' = 911
# the value of 'counter' = 912
# the value of 'counter' = 913
# the value of 'counter' = 914
# the value of 'counter' = 915
# the value of 'counter' = 916
# the value of 'counter' = 917
# the value of 'counter' = 918
# the value of 'counter' = 919
# the value of 'counter' = 920
# the value of 'counter' = 921
# the value of 'counter' = 922
# the value of 'counter' = 923
# the value of 'counter' = 924
# the value of 'counter' = 925
# the value of 'counter' = 926
# the value of 'counter' = 927
# the value of 'counter' = 928
# the value of 'counter' = 929
# the value of 'counter' = 930
# the value of 'counter' = 931
# the value of 'counter' = 932
# the value of 'counter' = 933
# the value of 'counter' = 934
# the value of 'counter' = 935
# the value of 'counter' = 936
# the value of 'counter' = 937
# the value of 'counter' = 938
# the value of 'counter' = 939
# the value of 'counter' = 940
# the value of 'counter' = 941
# the value of 'counter' = 942
# the value of 'counter' = 943
# the value of 'counter' = 944
# the value of 'counter' = 945
# the value of 'counter' = 946
# the value of 'counter' = 947
# the value of 'counter' = 948
# the value of 'counter' = 949
# the value of 'counter' = 950
# the value of 'counter' = 951
# the value of 'counter' = 952
# the value of 'counter' = 953
# the value of 'counter' = 954
# the value of 'counter' = 955
# the value of 'counter' = 956
# the value of 'counter' = 957
# the value of 'counter' = 958
# the value of 'counter' = 959
# the value of 'counter' = 960
# the value of 'counter' = 961
# the value of 'counter' = 962
# the value of 'counter' = 963
# the value of 'counter' = 964
# the value of 'counter' = 965
# the value of 'counter' = 966
# the value of 'counter' = 967
# the value of 'counter' = 968
# the value of 'counter' = 969
# the value of 'counter' = 970
# the value of 'counter' = 971
# the value of 'counter' = 972
# the value of 'counter' = 973
# the value of 'counter' = 974
# the value of 'counter' = 975
# the value of 'counter' = 976
# the value of 'counter' = 977
# the value of 'counter' = 978
# the value of 'counter' = 979
# the value of 'counter' = 980
# the value of 'counter' = 981
# the value of 'counter' = 982
# the value of 'counter' = 983
# the value of 'counter' = 984
# the value of 'counter' = 985
# the value of 'counter' = 986
# the value of 'counter' = 987
# the value of 'counter' = 988
# the value of 'counter' = 989
# the value of 'counter' = 990
# the value of 'counter' = 991
# the value of 'counter' = 992
# the value of 'counter' = 993
# the value of 'counter' = 994
# the value of 'counter' = 995
# the value of 'counter' = 996
# the value of 'counter' = 997
# the value of 'counter' = 998
# the value of 'counter' = 999
# the value of 'counter' = 1000
# the value of 'counter' = 1001
# the value of 'counter' = 1002
# the value of 'counter' = 1003
# the value of 'counter' = 1004
# the value of 'counter' = 1005
# the value of 'counter' = 1006
# the value of 'counter' = 1007
# the value of 'counter' = 1008
# the value of 'counter' = 1009
# the value of 'counter' = 1010
# the value of 'counter' = 1011
# the value of 'counter' = 1012
# the value of 'counter' = 1013
# the value of 'counter' = 1014
# the value of 'counter' = 1015
# the value of 'counter' = 1016
# the value of 'counter' = 1017
# the value of 'counter' = 1018
# the value of 'counter' = 1019
# the value of 'counter' = 1020
# the value of 'counter' = 1021
# the value of 'counter' = 1022
# the value of 'counter' = 1023
# the value of 'counter' = 1024
# the value of 'counter' = 1025
# the value of 'counter' = 1026
# the value of 'counter' = 1027
# the value of 'counter' = 1028
# the value of 'counter' = 1029
# the value of 'counter' = 1030
# the value of 'counter' = 1031
# the value of 'counter' = 1032
# the value of 'counter' = 1033
# the value of 'counter' = 1034
# the value of 'counter' = 1035
# the value of 'counter' = 1036
# the value of 'counter' = 1037
# the value of 'counter' = 1038
# the value of 'counter' = 1039
# the value of 'counter' = 1040
# the value of 'counter' = 1041
# the value of 'counter' = 1042
# the value of 'counter' = 1043
# the value of 'counter' = 1044
# the value of 'counter' = 1045
# the value of 'counter' = 1046
# the value of 'counter' = 1047
# the value of 'counter' = 1048
# the value of 'counter' = 1049
# the value of 'counter' = 1050
# the value of 'counter' = 1051
# the value of 'counter' = 1052
# the value of 'counter' = 1053
# the value of 'counter' = 1054
# the value of 'counter' = 1055
# the value of 'counter' = 1056
# the value of 'counter' = 1057
# the value of 'counter' = 1058
# the value of 'counter' = 1059
# the value of 'counter' = 1060
# the value of 'counter' = 1061
# the value of 'counter' = 1062
# the value of 'counter' = 1063
# the value of 'counter' = 1064
# the value of 'counter' = 1065
# the value of 'counter' = 1066
# the value of 'counter' = 1067
# the value of 'counter' = 1068
# the value of 'counter' = 1069
# the value of 'counter' = 1070
# the value of 'counter' = 1071
# the value of 'counter' = 1072
# the value of 'counter' = 1073
# the value of 'counter' = 1074
# the value of 'counter' = 1075
# the value of 'counter' = 1076
# the value of 'counter' = 1077
# the value of 'counter' = 1078
# the value of 'counter' = 1079
# the value of 'counter' = 1080
# the value of 'counter' = 1081
# the value of 'counter' = 1082
# the value of 'counter' = 1083
# the value of 'counter' = 1084
# the value of 'counter' = 1085
# the value of 'counter' = 1086
# the value of 'counter' = 1087
# the value of 'counter' = 1088
# the value of 'counter' = 1089
# the value of 'counter' = 1090
# the value of 'counter' = 1091
# the value of 'counter' = 1092
# the value of 'counter' = 1093
# the value of 'counter' = 1094
# the value of 'counter' = 1095
# the value of 'counter' = 1096
# the value of 'counter' = 1097
# the value of 'counter' = 1098
# the value of 'counter' = 1099
# the value of 'counter' = 1100
# the value of 'counter' = 1101
# the value of 'counter' = 1102
# the value of 'counter' = 1103
# the value of 'counter' = 1104
# the value of 'counter' = 1105
# the value of 'counter' = 1106
# the value of 'counter' = 1107
# the value of 'counter' = 1108
# the value of 'counter' = 1109
# the value of 'counter' = 1110
# the value of 'counter' = 1111
# the value of 'counter' = 1112
# the value of 'counter' = 1113
# the value of 'counter' = 1114
# the value of 'counter' = 1115
# the value of 'counter' = 1116
# the value of 'counter' = 1117
# the value of 'counter' = 1118
# the value of 'counter' = 1119
# the value of 'counter' = 1120
# the value of 'counter' = 1121
# the value of 'counter' = 1122
# the value of 'counter' = 1123
# the value of 'counter' = 1124
# the value of 'counter' = 1125
# the value of 'counter' = 1126
# the value of 'counter' = 1127
# the value of 'counter' = 1128
# the value of 'counter' = 1129
# the value of 'counter' = 1130
# the value of 'counter' = 1131
# the value of 'counter' = 1132
# the value of 'counter' = 1133
# the value of 'counter' = 1134
# the value of 'counter' = 1135
# the value of 'counter' = 1136
# the value of 'counter' = 1137
# the value of 'counter' = 1138
# the value of 'counter' = 1139
# the value of 'counter' = 1140
# the value of 'counter' = 1141
# the value of 'counter' = 1142
# the value of 'counter' = 1143
# the value of 'counter' = 1144
# the value of 'counter' = 1145
# the value of 'counter' = 1146
# the value of 'counter' = 1147
# the value of 'counter' = 1148
# the value of 'counter' = 1149
# the value of 'counter' = 1150
# the value of 'counter' = 1151
# the value of 'counter' = 1152
# the value of 'counter' = 1153
# the value of 'counter' = 1154
# the value of 'counter' = 1155
# the value of 'counter' = 1156
# the value of 'counter' = 1157
# the value of 'counter' = 1158
# the value of 'counter' = 1159
# the value of 'counter' = 1160
# the value of 'counter' = 1161
# the value of 'counter' = 1162
# the value of 'counter' = 1163
# the value of 'counter' = 1164
# the value of 'counter' = 1165
# the value of 'counter' = 1166
# the value of 'counter' = 1167
# the value of 'counter' = 1168
# the value of 'counter' = 1169
# the value of 'counter' = 1170
# the value of 'counter' = 1171
# the value of 'counter' = 1172
# the value of 'counter' = 1173
# the value of 'counter' = 1174
# the value of 'counter' = 1175
# the value of 'counter' = 1176
# the value of 'counter' = 1177
# the value of 'counter' = 1178
# the value of 'counter' = 1179
# the value of 'counter' = 1180
# the value of 'counter' = 1181
# the value of 'counter' = 1182
# the value of 'counter' = 1183
# the value of 'counter' = 1184
# the value of 'counter' = 1185
# the value of 'counter' = 1186
# the value of 'counter' = 1187
# the value of 'counter' = 1188
# the value of 'counter' = 1189
# the value of 'counter' = 1190
# the value of 'counter' = 1191
# the value of 'counter' = 1192
# the value of 'counter' = 1193
# the value of 'counter' = 1194
# the value of 'counter' = 1195
# the value of 'counter' = 1196
# the value of 'counter' = 1197
# the value of 'counter' = 1198
# the value of 'counter' = 1199
# the value of 'counter' = 1200
# the value of 'counter' = 1201
# the value of 'counter' = 1202
# the value of 'counter' = 1203
# the value of 'counter' = 1204
# the value of 'counter' = 1205
# the value of 'counter' = 1206
# the value of 'counter' = 1207
# the value of 'counter' = 1208
# the value of 'counter' = 1209
# the value of 'counter' = 1210
# the value of 'counter' = 1211
# the value of 'counter' = 1212
# the value of 'counter' = 1213
# the value of 'counter' = 1214
# the value of 'counter' = 1215
# the value of 'counter' = 1216
# the value of 'counter' = 1217
# the value of 'counter' = 1218
# the value of 'counter' = 1219
# the value of 'counter' = 1220
# the value of 'counter' = 1221
# the value of 'counter' = 1222
# the value of 'counter' = 1223
# the value of 'counter' = 1224
# the value of 'counter' = 1225
# the value of 'counter' = 1226
# the value of 'counter' = 1227
# the value of 'counter' = 1228
# the value of 'counter' = 1229
# the value of 'counter' = 1230
# the value of 'counter' = 1231
# the value of 'counter' = 1232
# the value of 'counter' = 1233
# the value of 'counter' = 1234
# the value of 'counter' = 1235
# the value of 'counter' = 1236
# the value of 'counter' = 1237
# the value of 'counter' = 1238
# the value of 'counter' = 1239
# the value of 'counter' = 1240
# the value of 'counter' = 1241
# the value of 'counter' = 1242
# the value of 'counter' = 1243
# the value of 'counter' = 1244
# the value of 'counter' = 1245
# the value of 'counter' = 1246
# the value of 'counter' = 1247
# the value of 'counter' = 1248
# the value of 'counter' = 1249
# the value of 'counter' = 1250
# the value of 'counter' = 1251
# the value of 'counter' = 1252
# the value of 'counter' = 1253
# the value of 'counter' = 1254
# the value of 'counter' = 1255
# the value of 'counter' = 1256
# the value of 'counter' = 1257
# the value of 'counter' = 1258
# the value of 'counter' = 1259
# the value of 'counter' = 1260
# the value of 'counter' = 1261
# the value of 'counter' = 1262
# the value of 'counter' = 1263
# the value of 'counter' = 1264
# the value of 'counter' = 1265
# the value of 'counter' = 1266
# the value of 'counter' = 1267
# the value of 'counter' = 1268
# the value of 'counter' = 1269
# the value of 'counter' = 1270
# the value of 'counter' = 1271
# the value of 'counter' = 1272
# the value of 'counter' = 1273
# the value of 'counter' = 1274
# the value of 'counter' = 1275
# the value of 'counter' = 1276
# the value of 'counter' = 1277
# the value of 'counter' = 1278
# the value of 'counter' = 1279
# the value of 'counter' = 1280
# the value of 'counter' = 1281
# the value of 'counter' = 1282
# the value of 'counter' = 1283
# the value of 'counter' = 1284
# the value of 'counter' = 1285
# the value of 'counter' = 1286
# the value of 'counter' = 1287
# the value of 'counter' = 1288
# the value of 'counter' = 1289
# the value of 'counter' = 1290
# the value of 'counter' = 1291
# the value of 'counter' = 1292
# the value of 'counter' = 1293
# the value of 'counter' = 1294
# the value of 'counter' = 1295
# the value of 'counter' = 1296
# the value of 'counter' = 1297
# the value of 'counter' = 1298
# the value of 'counter' = 1299
# the value of 'counter' = 1300
# the value of 'counter' = 1301
# the value of 'counter' = 1302
# the value of 'counter' = 1303
# the value of 'counter' = 1304
# the value of 'counter' = 1305
# the value of 'counter' = 1306
# the value of 'counter' = 1307
# the value of 'counter' = 1308
# the value of 'counter' = 1309
# the value of 'counter' = 1310
# the value of 'counter' = 1311
# the value of 'counter' = 1312
# the value of 'counter' = 1313
# the value of 'counter' = 1314
# the value of 'counter' = 1315
# the value of 'counter' = 1316
# the value of 'counter' = 1317
# the value of 'counter' = 1318
# the value of 'counter' = 1319
# the value of 'counter' = 1320
# the value of 'counter' = 1321
# the value of 'counter' = 1322
# the value of 'counter' = 1323
# the value of 'counter' = 1324
# the value of 'counter' = 1325
# the value of 'counter' = 1326
# the value of 'counter' = 1327
# the value of 'counter' = 1328
# the value of 'counter' = 1329
# the value of 'counter' = 1330
# the value of 'counter' = 1331
# the value of 'counter' = 1332
# the value of 'counter' = 1333
# the value of 'counter' = 1334
# the value of 'counter' = 1335
# the value of 'counter' = 1336
# the value of 'counter' = 1337
# the value of 'counter' = 1338
# the value of 'counter' = 1339
# the value of 'counter' = 1340
# the value of 'counter' = 1341
# the value of 'counter' = 1342
# the value of 'counter' = 1343
# the value of 'counter' = 1344
# the value of 'counter' = 1345
# the value of 'counter' = 1346
# the value of 'counter' = 1347
# the value of 'counter' = 1348
# the value of 'counter' = 1349
# the value of 'counter' = 1350
# the value of 'counter' = 1351
# the value of 'counter' = 1352
# the value of 'counter' = 1353
# the value of 'counter' = 1354
# the value of 'counter' = 1355
# the value of 'counter' = 1356
# the value of 'counter' = 1357
# the value of 'counter' = 1358
# the value of 'counter' = 1359
# the value of 'counter' = 1360
# the value of 'counter' = 1361
# the value of 'counter' = 1362
# the value of 'counter' = 1363
# the value of 'counter' = 1364
# the value of 'counter' = 1365
# the value of 'counter' = 1366
# the value of 'counter' = 1367
# the value of 'counter' = 1368
# the value of 'counter' = 1369
# the value of 'counter' = 1370
# the value of 'counter' = 1371
# the value of 'counter' = 1372
# the value of 'counter' = 1373
# the value of 'counter' = 1374
# the value of 'counter' = 1375
# the value of 'counter' = 1376
# the value of 'counter' = 1377
# the value of 'counter' = 1378
# the value of 'counter' = 1379
# the value of 'counter' = 1380
# the value of 'counter' = 1381
# the value of 'counter' = 1382
# the value of 'counter' = 1383
# the value of 'counter' = 1384
# the value of 'counter' = 1385
# the value of 'counter' = 1386
# the value of 'counter' = 1387
# the value of 'counter' = 1388
# the value of 'counter' = 1389
# the value of 'counter' = 1390
# the value of 'counter' = 1391
# the value of 'counter' = 1392
# the value of 'counter' = 1393
# the value of 'counter' = 1394
# the value of 'counter' = 1395
# the value of 'counter' = 1396
# the value of 'counter' = 1397
# the value of 'counter' = 1398
# the value of 'counter' = 1399
# the value of 'counter' = 1400
# the value of 'counter' = 1401
# the value of 'counter' = 1402
# the value of 'counter' = 1403
# the value of 'counter' = 1404
# the value of 'counter' = 1405
# the value of 'counter' = 1406
# the value of 'counter' = 1407
# the value of 'counter' = 1408
# the value of 'counter' = 1409
# the value of 'counter' = 1410
# the value of 'counter' = 1411
# the value of 'counter' = 1412
# the value of 'counter' = 1413
# the value of 'counter' = 1414
# the value of 'counter' = 1415
# the value of 'counter' = 1416
# the value of 'counter' = 1417
# the value of 'counter' = 1418
# the value of 'counter' = 1419
# the value of 'counter' = 1420
# the value of 'counter' = 1421
# the value of 'counter' = 1422
# the value of 'counter' = 1423
# the value of 'counter' = 1424
# the value of 'counter' = 1425
# the value of 'counter' = 1426
# the value of 'counter' = 1427
# the value of 'counter' = 1428
# the value of 'counter' = 1429
# the value of 'counter' = 1430
# the value of 'counter' = 1431
# the value of 'counter' = 1432
# the value of 'counter' = 1433
# the value of 'counter' = 1434
# the value of 'counter' = 1435
# the value of 'counter' = 1436
# the value of 'counter' = 1437
# the value of 'counter' = 1438
# the value of 'counter' = 1439
# the value of 'counter' = 1440
# the value of 'counter' = 1441
# the value of 'counter' = 1442
# the value of 'counter' = 1443
# the value of 'counter' = 1444
# the value of 'counter' = 1445
# the value of 'counter' = 1446
# the value of 'counter' = 1447
# the value of 'counter' = 1448
# the value of 'counter' = 1449
# the value of 'counter' = 1450
# the value of 'counter' = 1451
# the value of 'counter' = 1452
# the value of 'counter' = 1453
# the value of 'counter' = 1454
# the value of 'counter' = 1455
# the value of 'counter' = 1456
# the value of 'counter' = 1457
# the value of 'counter' = 1458
# the value of 'counter' = 1459
# the value of 'counter' = 1460
# the value of 'counter' = 1461
# the value of 'counter' = 1462
# the value of 'counter' = 1463
# the value of 'counter' = 1464
# the value of 'counter' = 1465
# the value of 'counter' = 1466
# the value of 'counter' = 1467
# the value of 'counter' = 1468
# the value of 'counter' = 1469
# the value of 'counter' = 1470
# the value of 'counter' = 1471
# the value of 'counter' = 1472
# the value of 'counter' = 1473
# the value of 'counter' = 1474
# the value of 'counter' = 1475
# the value of 'counter' = 1476
# the value of 'counter' = 1477
# the value of 'counter' = 1478
# the value of 'counter' = 1479
# the value of 'counter' = 1480
# the value of 'counter' = 1481
# the value of 'counter' = 1482
# the value of 'counter' = 1483
# the value of 'counter' = 1484
# the value of 'counter' = 1485
# the value of 'counter' = 1486
# the value of 'counter' = 1487
# the value of 'counter' = 1488
# the value of 'counter' = 1489
# the value of 'counter' = 1490
# the value of 'counter' = 1491
# the value of 'counter' = 1492
# the value of 'counter' = 1493
# the value of 'counter' = 1494
# the value of 'counter' = 1495
# the value of 'counter' = 1496
# the value of 'counter' = 1497
# the value of 'counter' = 1498
# the value of 'counter' = 1499
# the value of 'counter' = 1500
# the value of 'counter' = 1501
# the value of 'counter' = 1502
# the value of 'counter' = 1503
# the value of 'counter' = 1504
# the value of 'counter' = 1505
# the value of 'counter' = 1506
# the value of 'counter' = 1507
# the value of 'counter' = 1508
# the value of 'counter' = 1509
# the value of 'counter' = 1510
# the value of 'counter' = 1511
# the value of 'counter' = 1512
# the value of 'counter' = 1513
# the value of 'counter' = 1514
# the value of 'counter' = 1515
# the value of 'counter' = 1516
# the value of 'counter' = 1517
# the value of 'counter' = 1518
# the value of 'counter' = 1519
# the value of 'counter' = 1520
# the value of 'counter' = 1521
# the value of 'counter' = 1522
# the value of 'counter' = 1523
# the value of 'counter' = 1524
# the value of 'counter' = 1525
# the value of 'counter' = 1526
# the value of 'counter' = 1527
# the value of 'counter' = 1528
# the value of 'counter' = 1529
# the value of 'counter' = 1530
# the value of 'counter' = 1531
# the value of 'counter' = 1532
# the value of 'counter' = 1533
# the value of 'counter' = 1534
# the value of 'counter' = 1535
# the value of 'counter' = 1536
# the value of 'counter' = 1537
# the value of 'counter' = 1538
# the value of 'counter' = 1539
# the value of 'counter' = 1540
# the value of 'counter' = 1541
# the value of 'counter' = 1542
# the value of 'counter' = 1543
# the value of 'counter' = 1544
# the value of 'counter' = 1545
# the value of 'counter' = 1546
# the value of 'counter' = 1547
# the value of 'counter' = 1548
# the value of 'counter' = 1549
# the value of 'counter' = 1550
# the value of 'counter' = 1551
# the value of 'counter' = 1552
# the value of 'counter' = 1553
# the value of 'counter' = 1554
# the value of 'counter' = 1555
# the value of 'counter' = 1556
# the value of 'counter' = 1557
# the value of 'counter' = 1558
# the value of 'counter' = 1559
# the value of 'counter' = 1560
# the value of 'counter' = 1561
# the value of 'counter' = 1562
# the value of 'counter' = 1563
# the value of 'counter' = 1564
# the value of 'counter' = 1565
# the value of 'counter' = 1566
# the value of 'counter' = 1567
# the value of 'counter' = 1568
# the value of 'counter' = 1569
# the value of 'counter' = 1570
# the value of 'counter' = 1571
# the value of 'counter' = 1572
# the value of 'counter' = 1573
# the value of 'counter' = 1574
# the value of 'counter' = 1575
# the value of 'counter' = 1576
# the value of 'counter' = 1577
# the value of 'counter' = 1578
# the value of 'counter' = 1579
# the value of 'counter' = 1580
# the value of 'counter' = 1581
# the value of 'counter' = 1582
# the value of 'counter' = 1583
# the value of 'counter' = 1584
# the value of 'counter' = 1585
# the value of 'counter' = 1586
# the value of 'counter' = 1587
# the value of 'counter' = 1588
# the value of 'counter' = 1589
# the value of 'counter' = 1590
# the value of 'counter' = 1591
# the value of 'counter' = 1592
# the value of 'counter' = 1593
# the value of 'counter' = 1594
# the value of 'counter' = 1595
# the value of 'counter' = 1596
# the value of 'counter' = 1597
# the value of 'counter' = 1598
# the value of 'counter' = 1599
# the value of 'counter' = 1600
# the value of 'counter' = 1601
# the value of 'counter' = 1602
# the value of 'counter' = 1603
# the value of 'counter' = 1604
# the value of 'counter' = 1605
# the value of 'counter' = 1606
# the value of 'counter' = 1607
# the value of 'counter' = 1608
# the value of 'counter' = 1609
# the value of 'counter' = 1610
# the value of 'counter' = 1611
# the value of 'counter' = 1612
# the value of 'counter' = 1613
# the value of 'counter' = 1614
# the value of 'counter' = 1615
# the value of 'counter' = 1616
# the value of 'counter' = 1617
# the value of 'counter' = 1618
# the value of 'counter' = 1619
# the value of 'counter' = 1620
# the value of 'counter' = 1621
# the value of 'counter' = 1622
# the value of 'counter' = 1623
# the value of 'counter' = 1624
# the value of 'counter' = 1625
# the value of 'counter' = 1626
# the value of 'counter' = 1627
# the value of 'counter' = 1628
# the value of 'counter' = 1629
# the value of 'counter' = 1630
# the value of 'counter' = 1631
# the value of 'counter' = 1632
# the value of 'counter' = 1633
# the value of 'counter' = 1634
# the value of 'counter' = 1635
# the value of 'counter' = 1636
# ...
# the value of 'counter' = 54017
# the value of 'counter' = 54018
# the value of 'counter' = 54019
# the value of 'counter' = 54020
# the value of 'counter' = 54021
# the value of 'counter' = 54022
# the value of 'counter' = 54023
# the value of 'counter' = 54024
# the value of 'counter' = 54025
# the value of 'counter' = 54026
# the value of 'counter' = 54027
# the value of 'counter' = 54028
# the value of 'counter' = 54029
# the value of 'counter' = 54030
# the value of 'counter' = 54031
# the value of 'counter' = 54032
# the value of 'counter' = 54033
# the value of 'counter' = 54034
# the value of 'counter' = 54035
# the value of 'counter' = 54036
# the value of 'counter' = 54037
# the value of 'counter' = 54038
# the value of 'counter' = 54039
# the value of 'counter' = 54040
# the value of 'counter' = 54041
# the value of 'counter' = 54042
# the value of 'counter' = 54043
# the value of 'counter' = 54044
# the value of 'counter' = 54045
# the value of 'counter' = 54046
# the value of 'counter' = 54047
# the value of 'counter' = 54048
# the value of 'counter' = 54049
# the value of 'counter' = 54050
# the value of 'counter' = 54051
# the value of 'counter' = 54052
# the value of 'counter' = 54053
# the value of 'counter' = 54054
# the value of 'counter' = 54055
# the value of 'counter' = 54056
# the value of 'counter' = 54057
# the value of 'counter' = 54058
# the value of 'counter' = 54059
# the value of 'counter' = 54060
# the value of 'counter' = 54061
# the value of 'counter' = 54062
# the value of 'counter' = 54063
# the value of 'counter' = 54064
# the value of 'counter' = 54065
# the value of 'counter' = 54066
# the value of 'counter' = 54067
# the value of 'counter' = 54068
# the value of 'counter' = 54069
# the value of 'counter' = 54070
# the value of 'counter' = 54071
# the value of 'counter' = 54072
# the value of 'counter' = 54073
# the value of 'counter' = 54074
# the value of 'counter' = 54075
# the value of 'counter' = 54076
# the value of 'counter' = 54077
# the value of 'counter' = 54078
# the value of 'counter' = 54079
# the value of 'counter' = 54080
# the value of 'counter' = 54081
# the value of 'counter' = 54082
# the value of 'counter' = 54083
# the value of 'counter' = 54084
# the value of 'counter' = 54085
# the value of 'counter' = 54086
# the value of 'counter' = 54087
# the value of 'counter' = 54088
# the value of 'counter' = 54089
# the value of 'counter' = 54090
# the value of 'counter' = 54091
# the value of 'counter' = 54092
# the value of 'counter' = 54093
# the value of 'counter' = 54094
# the value of 'counter' = 54095
# the value of 'counter' = 54096
# the value of 'counter' = 54097
# the value of 'counter' = 54098
# the value of 'counter' = 54099
# the value of 'counter' = 54100
# the value of 'counter' = 54101
# the value of 'counter' = 54102
# the value of 'counter' = 54103
# the value of 'counter' = 54104
# the value of 'counter' = 54105
# the value of 'counter' = 54106
# the value of 'counter' = 54107
# the value of 'counter' = 54108
# the value of 'counter' = 54109
# the value of 'counter' = 54110
# the value of 'counter' = 54111
# the value of 'counter' = 54112
# the value of 'counter' = 54113
# the value of 'counter' = 54114
# the value of 'counter' = 54115
# the value of 'counter' = 54116
# the value of 'counter' = 54117
# the value of 'counter' = 54118
# the value of 'counter' = 54119
# the value of 'counter' = 54120
# the value of 'counter' = 54121
# the value of 'counter' = 54122
# the value of 'counter' = 54123
# the value of 'counter' = 54124
# the value of 'counter' = 54125
# the value of 'counter' = 54126
# the value of 'counter' = 54127
# the value of 'counter' = 54128
# the value of 'counter' = 54129
# the value of 'counter' = 54130
# the value of 'counter' = 54131
# the value of 'counter' = 54132
# the value of 'counter' = 54133
# the value of 'counter' = 54134
# the value of 'counter' = 54135
# the value of 'counter' = 54136
# the value of 'counter' = 54137
# the value of 'counter' = 54138
# the value of 'counter' = 54139
# the value of 'counter' = 54140
# the value of 'counter' = 54141
# the value of 'counter' = 54142
# the value of 'counter' = 54143
# the value of 'counter' = 54144
# the value of 'counter' = 54145
# the value of 'counter' = 54146
# the value of 'counter' = 54147
# the value of 'counter' = 54148
# the value of 'counter' = 54149
# the value of 'counter' = 54150
# the value of 'counter' = 54151
# the value of 'counter' = 54152
# the value of 'counter' = 54153
# the value of 'counter' = 54154
# the value of 'counter' = 54155
# the value of 'counter' = 54156
# the value of 'counter' = 54157
# the value of 'counter' = 54158
# the value of 'counter' = 54159
# the value of 'counter' = 54160
# the value of 'counter' = 54161
# the value of 'counter' = 54162
# the value of 'counter' = 54163
# the value of 'counter' = 54164
# the value of 'counter' = 54165
# the value of 'counter' = 54166
# the value of 'counter' = 54167
# the value of 'counter' = 54168
# the value of 'counter' = 54169
# the value of 'counter' = 54170
# the value of 'counter' = 54171
# the value of 'counter' = 54172
# the value of 'counter' = 54173
# the value of 'counter' = 54174
# the value of 'counter' = 54175
# the value of 'counter' = 54176
# the value of 'counter' = 54177
# the value of 'counter' = 54178
# the value of 'counter' = 54179
# the value of 'counter' = 54180
# the value of 'counter' = 54181
# the value of 'counter' = 54182
# the value of 'counter' = 54183
# the value of 'counter' = 54184
# the value of 'counter' = 54185
# the value of 'counter' = 54186
# the value of 'counter' = 54187
# the value of 'counter' = 54188
# the value of 'counter' = 54189
# the value of 'counter' = 54190
# the value of 'counter' = 54191
# the value of 'counter' = 54192
# the value of 'counter' = 54193
# the value of 'counter' = 54194
# the value of 'counter' = 54195
# the value of 'counter' = 54196
# the value of 'counter' = 54197
# the value of 'counter' = 54198
# the value of 'counter' = 54199
# the value of 'counter' = 54200
# the value of 'counter' = 54201
# the value of 'counter' = 54202
# the value of 'counter' = 54203
# the value of 'counter' = 54204
# the value of 'counter' = 54205
# the value of 'counter' = 54206
# the value of 'counter' = 54207
# the value of 'counter' = 54208
# the value of 'counter' = 54209
# the value of 'counter' = 54210
# the value of 'counter' = 54211
# the value of 'counter' = 54212
# the value of 'counter' = 54213
# the value of 'counter' = 54214
# the value of 'counter' = 54215
# the value of 'counter' = 54216
# the value of 'counter' = 54217
# the value of 'counter' = 54218
# the value of 'counter' = 54219
# the value of 'counter' = 54220
# the value of 'counter' = 54221
# the value of 'counter' = 54222
# the value of 'counter' = 54223
# the value of 'counter' = 54224
# the value of 'counter' = 54225
# the value of 'counter' = 54226
# the value of 'counter' = 54227
# the value of 'counter' = 54228
# the value of 'counter' = 54229
# the value of 'counter' = 54230
# the value of 'counter' = 54231
# the value of 'counter' = 54232
# the value of 'counter' = 54233
# the value of 'counter' = 54234
# the value of 'counter' = 54235
# the value of 'counter' = 54236
# the value of 'counter' = 54237
# the value of 'counter' = 54238
# the value of 'counter' = 54239
# the value of 'counter' = 54240
# the value of 'counter' = 54241
# the value of 'counter' = 54242
# the value of 'counter' = 54243
# the value of 'counter' = 54244
# the value of 'counter' = 54245
# the value of 'counter' = 54246
# the value of 'counter' = 54247
# the value of 'counter' = 54248
# the value of 'counter' = 54249
# the value of 'counter' = 54250
# the value of 'counter' = 54251
# the value of 'counter' = 54252
# the value of 'counter' = 54253
# the value of 'counter' = 54254
# the value of 'counter' = 54255
# the value of 'counter' = 54256
# the value of 'counter' = 54257
# the value of 'counter' = 54258
# the value of 'counter' = 54259
# the value of 'counter' = 54260
# the value of 'counter' = 54261
# the value of 'counter' = 54262
# the value of 'counter' = 54263
# the value of 'counter' = 54264
# the value of 'counter' = 54265
# the value of 'counter' = 54266
# the value of 'counter' = 54267
# the value of 'counter' = 54268
# the value of 'counter' = 54269
# the value of 'counter' = 54270
# the value of 'counter' = 54271
# the value of 'counter' = 54272
# the value of 'counter' = 54273
# the value of 'counter' = 54274
# the value of 'counter' = 54275
# the value of 'counter' = 54276
# the value of 'counter' = 54277
# the value of 'counter' = 54278
# the value of 'counter' = 54279
# the value of 'counter' = 54280
# the value of 'counter' = 54281
# the value of 'counter' = 54282
# the value of 'counter' = 54283
# the value of 'counter' = 54284
# the value of 'counter' = 54285
# the value of 'counter' = 54286
# the value of 'counter' = 54287
# the value of 'counter' = 54288
# the value of 'counter' = 54289
# the value of 'counter' = 54290
# the value of 'counter' = 54291
# the value of 'counter' = 54292
# the value of 'counter' = 54293
# the value of 'counter' = 54294
# the value of 'counter' = 54295
# the value of 'counter' = 54296
# the value of 'counter' = 54297
# the value of 'counter' = 54298
# the value of 'counter' = 54299
# the value of 'counter' = 54300
# the value of 'counter' = 54301
# the value of 'counter' = 54302
# the value of 'counter' = 54303
# the value of 'counter' = 54304
# the value of 'counter' = 54305
# the value of 'counter' = 54306
# the value of 'counter' = 54307
# the value of 'counter' = 54308
# the value of 'counter' = 54309
# the value of 'counter' = 54310
# the value of 'counter' = 54311
# the value of 'counter' = 54312
# the value of 'counter' = 54313
# the value of 'counter' = 54314
# the value of 'counter' = 54315
# the value of 'counter' = 54316
# the value of 'counter' = 54317
# the value of 'counter' = 54318
# the value of 'counter' = 54319
# the value of 'counter' = 54320
# the value of 'counter' = 54321
# the value of 'counter' = 54322
# the value of 'counter' = 54323
# the value of 'counter' = 54324
# the value of 'counter' = 54325
# the value of 'counter' = 54326
# the value of 'counter' = 54327
# the value of 'counter' = 54328
# the value of 'counter' = 54329
# the value of 'counter' = 54330
# the value of 'counter' = 54331
# the value of 'counter' = 54332
# the value of 'counter' = 54333
# the value of 'counter' = 54334
# the value of 'counter' = 54335
# the value of 'counter' = 54336
# the value of 'counter' = 54337
# the value of 'counter' = 54338
# the value of 'counter' = 54339
# the value of 'counter' = 54340
# the value of 'counter' = 54341
# the value of 'counter' = 54342
# the value of 'counter' = 54343
# the value of 'counter' = 54344
# the value of 'counter' = 54345
# the value of 'counter' = 54346
# the value of 'counter' = 54347
# the value of 'counter' = 54348
# the value of 'counter' = 54349
# the value of 'counter' = 54350
# the value of 'counter' = 54351
# the value of 'counter' = 54352
# the value of 'counter' = 54353
# the value of 'counter' = 54354
# the value of 'counter' = 54355
# the value of 'counter' = 54356
# the value of 'counter' = 54357
# the value of 'counter' = 54358
# the value of 'counter' = 54359
# the value of 'counter' = 54360
# the value of 'counter' = 54361
# the value of 'counter' = 54362
# the value of 'counter' = 54363
# the value of 'counter' = 54364
# the value of 'counter' = 54365
# the value of 'counter' = 54366
# the value of 'counter' = 54367
# the value of 'counter' = 54368
# the value of 'counter' = 54369
# the value of 'counter' = 54370
# the value of 'counter' = 54371
# the value of 'counter' = 54372
# the value of 'counter' = 54373
# the value of 'counter' = 54374
# the value of 'counter' = 54375
# the value of 'counter' = 54376
# the value of 'counter' = 54377
# the value of 'counter' = 54378
# the value of 'counter' = 54379
# the value of 'counter' = 54380
# the value of 'counter' = 54381
# the value of 'counter' = 54382
# the value of 'counter' = 54383
# the value of 'counter' = 54384
# the value of 'counter' = 54385
# the value of 'counter' = 54386
# the value of 'counter' = 54387
# the value of 'counter' = 54388
# the value of 'counter' = 54389
# the value of 'counter' = 54390
# the value of 'counter' = 54391
# the value of 'counter' = 54392
# the value of 'counter' = 54393
# the value of 'counter' = 54394
# the value of 'counter' = 54395
# the value of 'counter' = 54396
# the value of 'counter' = 54397
# the value of 'counter' = 54398
# the value of 'counter' = 54399
# the value of 'counter' = 54400
# the value of 'counter' = 54401
# the value of 'counter' = 54402
# the value of 'counter' = 54403
# the value of 'counter' = 54404
# the value of 'counter' = 54405
# the value of 'counter' = 54406
# the value of 'counter' = 54407
# the value of 'counter' = 54408
# the value of 'counter' = 54409
# the value of 'counter' = 54410
# the value of 'counter' = 54411
# the value of 'counter' = 54412
# the value of 'counter' = 54413
# the value of 'counter' = 54414
# the value of 'counter' = 54415
# the value of 'counter' = 54416
# the value of 'counter' = 54417
# the value of 'counter' = 54418
# the value of 'counter' = 54419
# the value of 'counter' = 54420
# the value of 'counter' = 54421
# the value of 'counter' = 54422
# the value of 'counter' = 54423
# the value of 'counter' = 54424
# the value of 'counter' = 54425
# the value of 'counter' = 54426
# the value of 'counter' = 54427
# the value of 'counter' = 54428
# the value of 'counter' = 54429
# the value of 'counter' = 54430
# the value of 'counter' = 54431
# the value of 'counter' = 54432
# the value of 'counter' = 54433
# the value of 'counter' = 54434
# the value of 'counter' = 54435
# the value of 'counter' = 54436
# the value of 'counter' = 54437
# the value of 'counter' = 54438
# the value of 'counter' = 54439
# the value of 'counter' = 54440
# the value of 'counter' = 54441
# the value of 'counter' = 54442
# the value of 'counter' = 54443
# the value of 'counter' = 54444
# the value of 'counter' = 54445
# the value of 'counter' = 54446
# the value of 'counter' = 54447
# the value of 'counter' = 54448
# the value of 'counter' = 54449
# the value of 'counter' = 54450
# the value of 'counter' = 54451
# the value of 'counter' = 54452
# the value of 'counter' = 54453
# the value of 'counter' = 54454
# the value of 'counter' = 54455
# the value of 'counter' = 54456
# the value of 'counter' = 54457
# the value of 'counter' = 54458
# the value of 'counter' = 54459
# the value of 'counter' = 54460
# the value of 'counter' = 54461
# the value of 'counter' = 54462
# the value of 'counter' = 54463
# the value of 'counter' = 54464
# the value of 'counter' = 54465
# the value of 'counter' = 54466
# the value of 'counter' = 54467
# the value of 'counter' = 54468
# the value of 'counter' = 54469
# the value of 'counter' = 54470
# the value of 'counter' = 54471
# the value of 'counter' = 54472
# the value of 'counter' = 54473
# the value of 'counter' = 54474
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-61147d942407> in <module>()
#       3 while True:
#       4
# ----> 5     print("the value of 'counter' = {}".format(counter))
#       6     counter +=1
#       7
#
# /anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py in write(self, string)
#     398             is_child = (not self._is_master_process())
#     399             # only touch the buffer in the IO thread to avoid races
# --> 400             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     401             if is_child:
#     402                 # newlines imply flush in subprocesses
#
# /anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# /anaconda3/lib/python3.7/site-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     390                                  copy_threshold=self.copy_threshold)
#     391             data.group = group
# --> 392         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     393
#     394     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /anaconda3/lib/python3.7/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %% [markdown]
# ###  Loop Explorations
#
# Now, explore using for and while loops and breaks.
#
# Here are some things to try, and questions to ask - each of which you should explore in code.
# - What happens if you use 'break' all by itself?
# - What are some different ways to loop through a list? tuple?
# - Write these combinations:
#     - a `for` loop with a `break`, a `for` loop with a `continue`
#     - a `while` loop with a `break`, a `while` loop with a `continue`
# - Write some loops that loop across lists:
#     - Write a loop that loops across, and prints out, all the elements of a list
#     - Write a loop that loops across, and prints out, every second element of a list
#     - Write a loop that loops across, and prints out, every element of a list in reverse order
#     - Write a loop that loops across, and prints out, the first half of a list
# - Write a loop with a conditional inside it.
# - Can you have loops inside loops? If you think so, try and write a nested loop.

# %%
# YOUR CODE EXPLORATIONS HERE

# %% [markdown]
# ### Nested Loop Challenge
#
# Using nested loops, you will print out a pattern that looks like this:
#
# 1 <br>
# 1 2 <br>
# 1 2 3 <br>
# 1 2 3 4 <br>
# 1 2 3 4 5 <br>
# 1 2 3 4 5 6 <br>
# 1 2 3 4 5 6 7
#
# Hints:
# - You can do this with two while loops, one inside the other.
# - You will have two indices counters, one for each loop.
# - For the print statement, it will look something like `print(index_inner, end=" ")`

# %% [markdown]
# If you get the above pattern working, try manipulating the code to print out different patterns, and with different symbols.

# %% [markdown]
# ## The End!
#
# This is the end of this Coding Lab!
#
# Be sure you've made a concerted effort to complete all the tasks specified in this lab. Then, go ahead and submit on datahub!
